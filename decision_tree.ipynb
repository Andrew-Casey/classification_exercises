# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns



import acquire as acq
import prepare as prep

# %%
#get titanic data and split
titanic = prep.prep_titanic()
titanic
# Out:
# csv file found and loaded
#      passenger_id  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0               0         0       3    male      1      0   7.2500        S
# 1               1         1       1  female      1      0  71.2833        C
# 2               2         1       3  female      0      0   7.9250        S
# 3               3         1       1  female      1      0  53.1000        S
# 4               4         0       3    male      0      0   8.0500        S
# ..            ...       ...     ...     ...    ...    ...      ...      ...
# 886           886         0       2    male      0      0  13.0000        S
# 887           887         1       1  female      0      0  30.0000        S
# 888           888         0       3  female      1      2  23.4500        S
# 889           889         1       1    male      0      0  30.0000        C
# 890           890         0       3    male      0      0   7.7500        Q
#
# ...

# %%
df = prep.split_data(titanic, 'survived')
df
# Out:
# (     passenger_id  survived  pclass     sex  sibsp  parch      fare embarked  \
#  455           455         1       3    male      0      0    7.8958        C
#  380           380         1       1  female      0      0  227.5250        C
#  492           492         0       1    male      0      0   30.5000        S
#  55             55         1       1    male      0      0   35.5000        S
#  243           243         0       3    male      0      0    7.1250        S
#  ..            ...       ...     ...     ...    ...    ...       ...      ...
#  695           695         0       2    male      0      0   13.5000        S
#  128           128         1       3  female      1      1   22.3583        C
#  636           636         0       3    male      0      0    7.9250        S
#  222           222         0       3    male      0      0    8.0500        S
#  496           496         1       1  female      1      0   78.2667        C
#
# ...

# %%
train,validate,test = df
train
# Out:
#      passenger_id  survived  pclass     sex  sibsp  parch      fare embarked  \
# 455           455         1       3    male      0      0    7.8958        C
# 380           380         1       1  female      0      0  227.5250        C
# 492           492         0       1    male      0      0   30.5000        S
# 55             55         1       1    male      0      0   35.5000        S
# 243           243         0       3    male      0      0    7.1250        S
# ..            ...       ...     ...     ...    ...    ...       ...      ...
# 695           695         0       2    male      0      0   13.5000        S
# 128           128         1       3  female      1      1   22.3583        C
# 636           636         0       3    male      0      0    7.9250        S
# 222           222         0       3    male      0      0    8.0500        S
# 496           496         1       1  female      1      0   78.2667        C
#
#      alone  sex_male  embarked_Q  embarked_S
# ...

# %%
train = train.drop(columns=['sex'])
validate = validate.drop(columns=['sex'])
test = test.drop(columns=['sex'])
train
# Out:
#      passenger_id  survived  pclass  sibsp  parch      fare embarked  alone  \
# 455           455         1       3      0      0    7.8958        C      1
# 380           380         1       1      0      0  227.5250        C      1
# 492           492         0       1      0      0   30.5000        S      1
# 55             55         1       1      0      0   35.5000        S      1
# 243           243         0       3      0      0    7.1250        S      1
# ..            ...       ...     ...    ...    ...       ...      ...    ...
# 695           695         0       2      0      0   13.5000        S      1
# 128           128         1       3      1      1   22.3583        C      0
# 636           636         0       3      0      0    7.9250        S      1
# 222           222         0       3      0      0    8.0500        S      1
# 496           496         1       1      1      0   78.2667        C      0
#
#      sex_male  embarked_Q  embarked_S
# ...

# %%
train = train.drop(columns=['embarked'])
validate = validate.drop(columns=['embarked'])
test = test.drop(columns=['embarked'])
train
# Out:
#      passenger_id  survived  pclass  sibsp  parch      fare  alone  sex_male  \
# 455           455         1       3      0      0    7.8958      1         1
# 380           380         1       1      0      0  227.5250      1         0
# 492           492         0       1      0      0   30.5000      1         1
# 55             55         1       1      0      0   35.5000      1         1
# 243           243         0       3      0      0    7.1250      1         1
# ..            ...       ...     ...    ...    ...       ...    ...       ...
# 695           695         0       2      0      0   13.5000      1         1
# 128           128         1       3      1      1   22.3583      0         0
# 636           636         0       3      0      0    7.9250      1         1
# 222           222         0       3      0      0    8.0500      1         1
# 496           496         1       1      1      0   78.2667      0         0
#
#      embarked_Q  embarked_S
# ...

# %%
train.head()
# Out:
#      passenger_id  survived  pclass  sibsp  parch      fare  alone  sex_male  \
# 455           455         1       3      0      0    7.8958      1         1
# 380           380         1       1      0      0  227.5250      1         0
# 492           492         0       1      0      0   30.5000      1         1
# 55             55         1       1      0      0   35.5000      1         1
# 243           243         0       3      0      0    7.1250      1         1
#
#      embarked_Q  embarked_S
# 455           0           0
# 380           0           0
# 492           0           1
# 55            0           1
# 243           0           1

# %%
X_train = train.iloc[:,2:]
X_train
# Out:
#      pclass  sibsp  parch      fare  alone  sex_male  embarked_Q  embarked_S
# 455       3      0      0    7.8958      1         1           0           0
# 380       1      0      0  227.5250      1         0           0           0
# 492       1      0      0   30.5000      1         1           0           1
# 55        1      0      0   35.5000      1         1           0           1
# 243       3      0      0    7.1250      1         1           0           1
# ..      ...    ...    ...       ...    ...       ...         ...         ...
# 695       2      0      0   13.5000      1         1           0           1
# 128       3      1      1   22.3583      0         0           0           0
# 636       3      0      0    7.9250      1         1           0           1
# 222       3      0      0    8.0500      1         1           0           1
# 496       1      1      0   78.2667      0         0           0           0
#
# [534 rows x 8 columns]

# %%
X_validate = validate.iloc[:,2:]
X_validate
# Out:
#      pclass  sibsp  parch     fare  alone  sex_male  embarked_Q  embarked_S
# 176       3      3      1  25.4667      0         1           0           1
# 372       3      0      0   8.0500      1         1           0           1
# 678       3      1      6  46.9000      0         0           0           1
# 778       3      0      0   7.7375      1         1           1           0
# 463       2      0      0  13.0000      1         1           0           1
# ..      ...    ...    ...      ...    ...       ...         ...         ...
# 622       3      1      1  15.7417      0         1           0           0
# 302       3      0      0   0.0000      1         1           0           1
# 518       2      1      0  26.0000      0         0           0           1
# 765       1      1      0  77.9583      0         0           0           1
# 837       3      0      0   8.0500      1         1           0           1
#
# [178 rows x 8 columns]

# %%
X_test = test.iloc[:,2:]
X_test
# Out:
#      pclass  sibsp  parch      fare  alone  sex_male  embarked_Q  embarked_S
# 561       3      0      0    7.8958      1         1           0           1
# 641       1      0      0   69.3000      1         0           0           0
# 400       3      0      0    7.9250      1         1           0           1
# 498       1      1      2  151.5500      0         0           0           1
# 875       3      0      0    7.2250      1         0           0           0
# ..      ...    ...    ...       ...    ...       ...         ...         ...
# 339       1      0      0   35.5000      1         1           0           1
# 841       2      0      0   10.5000      1         1           0           1
# 442       3      1      0    7.7750      0         1           0           1
# 815       1      0      0    0.0000      1         1           0           1
# 53        2      1      0   26.0000      0         0           0           1
#
# [179 rows x 8 columns]

# %%
#set target
target = 'survived'

# %%
y_train = train[target]
y_train
# Out:
# 455    1
# 380    1
# 492    0
# 55     1
# 243    0
#       ..
# 695    0
# 128    1
# 636    0
# 222    0
# 496    1
# Name: survived, Length: 534, dtype: int64

# %%
y_validate = validate[target]
y_validate
# Out:
# 176    0
# 372    0
# 678    0
# 778    0
# 463    0
#       ..
# 622    1
# 302    0
# 518    1
# 765    1
# 837    0
# Name: survived, Length: 178, dtype: int64

# %%
y_test = test[target]
y_test
# Out:
# 561    0
# 641    1
# 400    1
# 498    0
# 875    1
#       ..
# 339    0
# 841    0
# 442    0
# 815    0
# 53     1
# Name: survived, Length: 179, dtype: int64

# %% [markdown]
# What is your baseline prediction? What is your baseline accuracy? remember: your baseline prediction for a classification problem is predicting the most prevelant class in the training dataset (the mode). When you make those predictions, what is your accuracy? This is your baseline accuracy.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# didn't survive is the baseline prediction
train.survived.value_counts()
# Out:
# 0    329
# 1    205
# Name: survived, dtype: int64

# %%
(train.survived == 0).mean()
# Out:
# 0.6161048689138576

# %%
baseline_accuracy = 329/ (329 + 205)
baseline_accuracy
# Out:
# 0.6161048689138576

# %% [markdown]
# Fit the decision tree classifier to your training sample and transform (i.e. make predictions on the training sample)

# %%
tree1 = DecisionTreeClassifier()
tree1
# Out:
# DecisionTreeClassifier()

# %%
tree1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree1.score(X_train,y_train)
# Out:
# 0.9456928838951311

# %%
#see predictions
tree1.predict(X_train)[:5]
# Out:
# array([0, 1, 0, 1, 0])

# %% [markdown]
# Evaluate your in-sample results using the model score, confusion matrix, and classification report.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
tree1.score(X_train,y_train)
# Out:
# 0.9456928838951311

# %%
y_pred = tree1.predict(X_train)
y_pred[:5]
# Out:
# array([0, 1, 0, 1, 0])

# %%
confusion_matrix(y_train, y_pred)
# Out:
# array([[327,   2],
#        [ 27, 178]])

# %%
labels = sorted(y_train.unique())
labels
# Out:
# [0, 1]

# %%
pd.DataFrame(confusion_matrix(y_train, y_pred),
            index=[labels],
            columns = labels)
# Out:
#      0    1
# 0  327    2
# 1   27  178

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       329
#            1       0.99      0.87      0.92       205
#
#     accuracy                           0.95       534
#    macro avg       0.96      0.93      0.94       534
# weighted avg       0.95      0.95      0.94       534

# %%
from sklearn.tree import plot_tree

# %%
from sklearn.tree import export_text

print(export_text(tree1, feature_names=X_train.columns.to_list()))
# Out:
# |--- sex_male <= 0.50
# |   |--- pclass <= 2.50
# |   |   |--- fare <= 28.86
# |   |   |   |--- fare <= 28.23
# |   |   |   |   |--- fare <= 22.00
# |   |   |   |   |   |--- fare <= 20.25
# |   |   |   |   |   |   |--- fare <= 13.25
# |   |   |   |   |   |   |   |--- fare <= 12.82
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- fare >  12.82
# |   |   |   |   |   |   |   |   |--- parch <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- parch >  1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- fare >  13.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- fare >  20.25
# |   |   |   |   |   |   |--- alone <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- alone >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- fare >  22.00
# |   |   |   |   |   |--- class: 1
# ...

# %%
#see the tree that was built
#plot_tree
plt.figure(figsize = (12,6))
plot_tree(tree1,
         feature_names = X_train.columns,
         filled=True)
plt.show()

# %% [markdown]
# Compute: Accuracy, true positive rate, false positive rate, true negative rate, false negative rate, precision, recall, f1-score, and support.

# %%
#accuracy
tree1.score(X_train,y_train)
# Out:
# 0.9456928838951311

# %%
#true positive rate, false positive rate, true negative rate, false negative rate
pd.DataFrame(confusion_matrix(y_train, y_pred),
            index=[labels],
            columns = labels)
# Out:
#      0    1
# 0  327    2
# 1   27  178

# %% [markdown]
# - TP = 178
# - TN = 327
# - FP = 2
# - FN = 27

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       329
#            1       0.99      0.87      0.92       205
#
#     accuracy                           0.95       534
#    macro avg       0.96      0.93      0.94       534
# weighted avg       0.95      0.95      0.94       534

# %% [markdown]
# - precision, recall, f1-score, and support
#     - precision = 0.92
#     - recall = .99
#     - f1-score = .96
#     - support = 329

# %% [markdown]
# Run through steps 2-4 using a different max_depth value.

# %%
for x in range(1,20):
#    print(x)
    tree = DecisionTreeClassifier(max_depth = x)
    tree.fit(X_train, y_train)
    acc = tree.score(X_train,y_train)
    print(f' for depth of {x:2}, the accuracy is {round(acc,2)}')
# Out:
#  for depth of  1, the accuracy is 0.79
#  for depth of  2, the accuracy is 0.79
#  for depth of  3, the accuracy is 0.82
#  for depth of  4, the accuracy is 0.82
#  for depth of  5, the accuracy is 0.83
#  for depth of  6, the accuracy is 0.86
#  for depth of  7, the accuracy is 0.86
#  for depth of  8, the accuracy is 0.9
#  for depth of  9, the accuracy is 0.91
#  for depth of 10, the accuracy is 0.92
#  for depth of 11, the accuracy is 0.93
#  for depth of 12, the accuracy is 0.93
#  for depth of 13, the accuracy is 0.94
#  for depth of 14, the accuracy is 0.94
#  for depth of 15, the accuracy is 0.94
#  for depth of 16, the accuracy is 0.95
#  for depth of 17, the accuracy is 0.95
#  for depth of 18, the accuracy is 0.95
#  for depth of 19, the accuracy is 0.95

# %% [markdown]
# # max depth 10

# %%
tree2 = DecisionTreeClassifier(max_depth = 10)
tree2
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
tree2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
tree2.score(X_train,y_train)
# Out:
# 0.9194756554307116

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(tree2,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       329
#            1       0.99      0.87      0.92       205
#
#     accuracy                           0.95       534
#    macro avg       0.96      0.93      0.94       534
# weighted avg       0.95      0.95      0.94       534

# %% [markdown]
# # max depth 8

# %%
tree3 = DecisionTreeClassifier(max_depth = 8)
tree3
# Out:
# DecisionTreeClassifier(max_depth=8)

# %%
tree3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=8)

# %%
tree3.score(X_train,y_train)
# Out:
# 0.9026217228464419

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(tree3,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       329
#            1       0.99      0.87      0.92       205
#
#     accuracy                           0.95       534
#    macro avg       0.96      0.93      0.94       534
# weighted avg       0.95      0.95      0.94       534

# %% [markdown]
# # max depth 6

# %%
tree4 = DecisionTreeClassifier(max_depth = 6)
tree4
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
tree4.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
tree4.score(X_train,y_train)
# Out:
# 0.8595505617977528

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(tree4,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       329
#            1       0.99      0.87      0.92       205
#
#     accuracy                           0.95       534
#    macro avg       0.96      0.93      0.94       534
# weighted avg       0.95      0.95      0.94       534

# %% [markdown]
# # max depth 5

# %%
tree5 = DecisionTreeClassifier(max_depth=5)
tree5
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
tree5.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
tree5.score(X_train,y_train)
# Out:
# 0.8333333333333334

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(tree5,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       329
#            1       0.99      0.87      0.92       205
#
#     accuracy                           0.95       534
#    macro avg       0.96      0.93      0.94       534
# weighted avg       0.95      0.95      0.94       534

# %% [markdown]
# # max depth 12

# %%
tree6 = DecisionTreeClassifier(max_depth = 12)
tree1
# Out:
# DecisionTreeClassifier()

# %%
tree6.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=12)

# %%
tree6.score(X_train,y_train)
# Out:
# 0.9344569288389513

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(tree6,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       329
#            1       0.99      0.87      0.92       205
#
#     accuracy                           0.95       534
#    macro avg       0.96      0.93      0.94       534
# weighted avg       0.95      0.95      0.94       534

# %% [markdown]
# Which model performs better on your in-sample data?

# %% [markdown]
# - model(tree1) with no max_depth identified is running the best on the train data set

# %%
tree1.score(X_train, y_train)
# Out:
# 0.9456928838951311

# %%
tree2.score(X_train, y_train)
# Out:
# 0.9194756554307116

# %%
tree3.score(X_train, y_train)
# Out:
# 0.9026217228464419

# %%
tree4.score(X_train, y_train)
# Out:
# 0.8595505617977528

# %%
tree5.score(X_train, y_train)
# Out:
# 0.8333333333333334

# %%
tree6.score(X_train, y_train)
# Out:
# 0.9344569288389513

# %% [markdown]
# Which model performs best on your out-of-sample data, the validate set?
# - model(tree3) schores the best on the validate set

# %%
tree1.score(X_validate, y_validate)
# Out:
# 0.7359550561797753

# %%
tree2.score(X_validate, y_validate)
# Out:
# 0.7584269662921348

# %%
tree3.score(X_validate, y_validate)
# Out:
# 0.7752808988764045

# %%
tree4.score(X_validate, y_validate)
# Out:
# 0.7752808988764045

# %%
tree5.score(X_validate, y_validate)
# Out:
# 0.7359550561797753

# %%
tree6.score(X_validate, y_validate)
# Out:
# 0.7415730337078652

# %%
scores_all = []
for x in range(1,20):
#    print(x)
    tree = DecisionTreeClassifier(max_depth = x)
    tree.fit(X_train, y_train)
    train_acc = tree.score(X_train,y_train)
   
    
    val_acc = tree.score(X_validate, y_validate)
    scores_all.append([x, train_acc, val_acc])
scores_all
# Out:
# [[1, 0.7921348314606742, 0.7752808988764045],
#  [2, 0.7921348314606742, 0.7752808988764045],
#  [3, 0.8183520599250936, 0.7921348314606742],
#  [4, 0.8202247191011236, 0.7921348314606742],
#  [5, 0.8333333333333334, 0.7303370786516854],
#  [6, 0.8595505617977528, 0.7808988764044944],
#  [7, 0.8651685393258427, 0.7752808988764045],
#  [8, 0.9026217228464419, 0.7752808988764045],
#  [9, 0.9101123595505618, 0.7752808988764045],
#  [10, 0.9194756554307116, 0.7528089887640449],
#  [11, 0.9250936329588015, 0.7584269662921348],
#  [12, 0.9344569288389513, 0.7471910112359551],
#  [13, 0.9400749063670412, 0.7415730337078652],
#  [14, 0.9400749063670412, 0.7415730337078652],
#  [15, 0.9456928838951311, 0.7303370786516854],
#  [16, 0.9456928838951311, 0.7359550561797753],
#  [17, 0.9456928838951311, 0.7359550561797753],
#  [18, 0.9456928838951311, 0.7303370786516854],
#  [19, 0.9456928838951311, 0.7415730337078652]]

# %%
scores_df = pd.DataFrame(scores_all, columns=['max_depth', 'train_acc','val_acc'])
scores_df
# Out:
#     max_depth  train_acc   val_acc
# 0           1   0.792135  0.775281
# 1           2   0.792135  0.775281
# 2           3   0.818352  0.792135
# 3           4   0.820225  0.792135
# 4           5   0.833333  0.730337
# 5           6   0.859551  0.780899
# 6           7   0.865169  0.775281
# 7           8   0.902622  0.775281
# 8           9   0.910112  0.775281
# 9          10   0.919476  0.752809
# 10         11   0.925094  0.758427
# 11         12   0.934457  0.747191
# 12         13   0.940075  0.741573
# 13         14   0.940075  0.741573
# 14         15   0.945693  0.730337
# 15         16   0.945693  0.735955
# 16         17   0.945693  0.735955
# 17         18   0.945693  0.730337
# 18         19   0.945693  0.741573

# %% [markdown]
# # do it again but with telco_churn

# %%
telco = prep.prep_telco()
telco.T
# Out:
# csv file found and loaded
#                                                0               1     \
# payment_type_id                                   2               2
# internet_service_type_id                          1               1
# contract_type_id                                  2               1
# customer_id                              0002-ORFBO      0003-MKNFE
# gender                                       Female            Male
# senior_citizen                                    0               0
# partner                                         Yes              No
# dependents                                      Yes              No
# tenure                                            9               9
# phone_service                                   Yes             Yes
# multiple_lines                                   No             Yes
# online_security                                  No              No
# ...

# %%
df = prep.split_data(telco, 'churn')
df
# Out:
# (      payment_type_id  internet_service_type_id  contract_type_id customer_id  \
#  5911                3                         1                 2  8319-QBEHW
#  2479                1                         3                 2  3547-LQRIK
#  5889                2                         1                 1  8280-MQRQN
#  6087                3                         1                 3  8626-PTQGE
#  785                 4                         2                 2  1142-IHLOO
#  ...               ...                       ...               ...         ...
#  6102                3                         2                 1  8642-GVWRF
#  356                 1                         1                 1  0523-VNGTF
#  1756                1                         2                 1  2568-BRGYX
#  2127                2                         1                 3  3057-VJJQE
#  3586                2                         1                 2  5081-NWSUP
#
# ...

# %%
train,validate,test = df
train.T
# Out:
#                                                             5911  \
# payment_type_id                                                3
# internet_service_type_id                                       1
# contract_type_id                                               2
# customer_id                                           8319-QBEHW
# gender                                                      Male
# senior_citizen                                                 0
# partner                                                       No
# dependents                                                   Yes
# tenure                                                        26
# phone_service                                                 No
# multiple_lines                                  No phone service
# online_security                                               No
# online_backup                                                Yes
# ...

# %%
train = train.drop(columns=['payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id','gender',
                           'senior_citizen','partner','dependents','phone_service','multiple_lines','online_security',
                           'online_backup','device_protection','tech_support','streaming_tv','streaming_movies','paperless_billing',
                           'churn', 'contract_type','internet_service_type','payment_type'])
validate = validate.drop(columns=['payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id','gender',
                           'senior_citizen','partner','dependents','phone_service','multiple_lines','online_security',
                           'online_backup','device_protection','tech_support','streaming_tv','streaming_movies','paperless_billing',
                           'churn', 'contract_type','internet_service_type','payment_type'])
test = test.drop(columns=['payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id','gender',
                           'senior_citizen','partner','dependents','phone_service','multiple_lines','online_security',
                           'online_backup','device_protection','tech_support','streaming_tv','streaming_movies','paperless_billing',
                           'churn', 'contract_type','internet_service_type','payment_type'])
train
# Out:
#       tenure  monthly_charges  total_charges  gender_encoded  \
# 5911      26            39.95        1023.75               1
# 2479      47            26.90        1250.85               0
# 5889       1            50.45          50.45               0
# 6087      69            60.05        4176.70               1
# 785       51            87.55        4475.90               0
# ...      ...              ...            ...             ...
# 6102       2            79.70         165.00               0
# 356       52            50.50        2566.30               0
# 1756       4            70.20         237.95               1
# 2127      35            55.25        1924.10               1
# 3586      10            64.90         685.55               0
#
#       senior_citizen_encoded  partner_encoded  dependents_encoded  \
# 5911                       0                0                   1
# 2479                       0                1                   0
# ...

# %%
column_to_move = train.pop("churn_encoded")
train.insert(0, "churn_encoded", column_to_move)
train
# Out:
#       churn_encoded  tenure  monthly_charges  total_charges  gender_encoded  \
# 5911              0      26            39.95        1023.75               1
# 2479              0      47            26.90        1250.85               0
# 5889              1       1            50.45          50.45               0
# 6087              0      69            60.05        4176.70               1
# 785               0      51            87.55        4475.90               0
# ...             ...     ...              ...            ...             ...
# 6102              1       2            79.70         165.00               0
# 356               0      52            50.50        2566.30               0
# 1756              1       4            70.20         237.95               1
# 2127              0      35            55.25        1924.10               1
# 3586              0      10            64.90         685.55               0
#
# ...

# %%
column_to_move = validate.pop("churn_encoded")
validate.insert(0, "churn_encoded", column_to_move)
validate
# Out:
#       churn_encoded  tenure  monthly_charges  total_charges  gender_encoded  \
# 3554              0      56           106.80        5914.40               0
# 2063              0      67            60.50        3870.00               0
# 1737              1      17            76.45        1233.40               1
# 5894              0      45            24.65        1138.80               0
# 209               1      68           100.20        6851.65               0
# ...             ...     ...              ...            ...             ...
# 2529              1      14           100.20        1369.80               0
# 6540              1      13            74.40         896.75               1
# 5765              0      72           106.30        7565.35               1
# 6959              0      34            67.65        2339.30               0
# 3108              0      61           101.15        6383.90               0
#
# ...

# %%
column_to_move = test.pop("churn_encoded")
test.insert(0, "churn_encoded", column_to_move)
test
# Out:
#       churn_encoded  tenure  monthly_charges  total_charges  gender_encoded  \
# 3160              0      51            95.15        5000.05               0
# 1577              0      65            71.00        4386.20               0
# 6823              1      18            96.05        1740.70               0
# 3615              0      25           105.50        2686.05               1
# 882               1       4            88.85         372.45               0
# ...             ...     ...              ...            ...             ...
# 1097              1       2            76.40         160.80               0
# 6441              1       1            45.70          45.70               1
# 5985              0      67            25.60        1790.35               0
# 2452              0      72            38.50        2763.00               1
# 983               1      11            74.55         824.75               1
#
# ...

# %%
X_train = train.iloc[:,1:]
X_train
# Out:
#       tenure  monthly_charges  total_charges  gender_encoded  \
# 5911      26            39.95        1023.75               1
# 2479      47            26.90        1250.85               0
# 5889       1            50.45          50.45               0
# 6087      69            60.05        4176.70               1
# 785       51            87.55        4475.90               0
# ...      ...              ...            ...             ...
# 6102       2            79.70         165.00               0
# 356       52            50.50        2566.30               0
# 1756       4            70.20         237.95               1
# 2127      35            55.25        1924.10               1
# 3586      10            64.90         685.55               0
#
#       senior_citizen_encoded  partner_encoded  dependents_encoded  \
# 5911                       0                0                   1
# 2479                       0                1                   0
# ...

# %%
X_validate = validate.iloc[:,1:]
X_validate
# Out:
#       tenure  monthly_charges  total_charges  gender_encoded  \
# 3554      56           106.80        5914.40               0
# 2063      67            60.50        3870.00               0
# 1737      17            76.45        1233.40               1
# 5894      45            24.65        1138.80               0
# 209       68           100.20        6851.65               0
# ...      ...              ...            ...             ...
# 2529      14           100.20        1369.80               0
# 6540      13            74.40         896.75               1
# 5765      72           106.30        7565.35               1
# 6959      34            67.65        2339.30               0
# 3108      61           101.15        6383.90               0
#
#       senior_citizen_encoded  partner_encoded  dependents_encoded  \
# 3554                       0                0                   0
# 2063                       0                0                   0
# ...

# %%
X_test = test.iloc[:,1:]
X_test
# Out:
#       tenure  monthly_charges  total_charges  gender_encoded  \
# 3160      51            95.15        5000.05               0
# 1577      65            71.00        4386.20               0
# 6823      18            96.05        1740.70               0
# 3615      25           105.50        2686.05               1
# 882        4            88.85         372.45               0
# ...      ...              ...            ...             ...
# 1097       2            76.40         160.80               0
# 6441       1            45.70          45.70               1
# 5985      67            25.60        1790.35               0
# 2452      72            38.50        2763.00               1
# 983       11            74.55         824.75               1
#
#       senior_citizen_encoded  partner_encoded  dependents_encoded  \
# 3160                       0                1                   1
# 1577                       0                1                   0
# ...

# %%
target = 'churn_encoded'

# %%
y_train = train[target]
y_train
# Out:
# 5911    0
# 2479    0
# 5889    1
# 6087    0
# 785     0
#        ..
# 6102    1
# 356     0
# 1756    1
# 2127    0
# 3586    0
# Name: churn_encoded, Length: 4225, dtype: int64

# %%
y_validate = validate[target]
y_validate
# Out:
# 3554    0
# 2063    0
# 1737    1
# 5894    0
# 209     1
#        ..
# 2529    1
# 6540    1
# 5765    0
# 6959    0
# 3108    0
# Name: churn_encoded, Length: 1409, dtype: int64

# %%
y_test = test[target]
y_test
# Out:
# 3160    0
# 1577    0
# 6823    1
# 3615    0
# 882     1
#        ..
# 1097    1
# 6441    1
# 5985    0
# 2452    0
# 983     1
# Name: churn_encoded, Length: 1409, dtype: int64

# %% [markdown]
# What is your baseline prediction? What is your baseline accuracy? remember: your baseline prediction for a classification problem is predicting the most prevelant class in the training dataset (the mode). When you make those predictions, what is your accuracy? This is your baseline accuracy.

# %%
train.churn_encoded.value_counts()
# Out:
# 0    3104
# 1    1121
# Name: churn_encoded, dtype: int64

# %%
baseline_accuracy = 3104/(3104+1121)
baseline_accuracy
# Out:
# 0.7346745562130178

# %% [markdown]
# Fit the decision tree classifier to your training sample and transform (i.e. make predictions on the training sample)

# %%
t1 = DecisionTreeClassifier()
t1
# Out:
# DecisionTreeClassifier()

# %%
t1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
t1.score(X_train, y_train)
# Out:
# 0.9981065088757396

# %%
t1.predict(X_train)
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
y_pred = t1.predict(X_train)
y_pred[:5]
# Out:
# array([0, 0, 1, 0, 0])

# %%
confusion_matrix(y_train, y_pred)
# Out:
# array([[3103,    1],
#        [   7, 1114]])

# %%
labels = sorted(y_train.unique())
labels
# Out:
# [0, 1]

# %%
pd.DataFrame(confusion_matrix(y_train, y_pred),
            index=[labels],
            columns = labels)
# Out:
#       0     1
# 0  3103     1
# 1     7  1114

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3104
#            1       1.00      0.99      1.00      1121
#
#     accuracy                           1.00      4225
#    macro avg       1.00      1.00      1.00      4225
# weighted avg       1.00      1.00      1.00      4225

# %%
plt.figure(figsize = (12,6))
plot_tree(tree1,
         feature_names = X_train.columns,
         filled=True)
plt.show()

# %% [markdown]
# # changing hyperparameters

# %%
t1.score(X_train,y_train)
# Out:
# 0.9981065088757396

# %%
pd.DataFrame(confusion_matrix(y_train, y_pred),
            index=[labels],
            columns = labels)
# Out:
#       0     1
# 0  3103     1
# 1     7  1114

# %% [markdown]
# - TP = 3103
# - TN = 1114
# - FP = 1
# - FN = 7

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3104
#            1       1.00      0.99      1.00      1121
#
#     accuracy                           1.00      4225
#    macro avg       1.00      1.00      1.00      4225
# weighted avg       1.00      1.00      1.00      4225

# %% [markdown]
# - precision, recall, f1-score, and support
#     - precision = 1.00
#     - recall = .99
#     - f1-score = 1.00
#     - support = 1121

# %% [markdown]
# # do it again

# %% [markdown]
# # max depth 10

# %%
t2 = DecisionTreeClassifier(max_depth = 10)
t2
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t2.score(X_train,y_train)
# Out:
# 0.8847337278106508

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(t2,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3104
#            1       1.00      0.99      1.00      1121
#
#     accuracy                           1.00      4225
#    macro avg       1.00      1.00      1.00      4225
# weighted avg       1.00      1.00      1.00      4225

# %% [markdown]
# # max depth 8

# %%
t3 = DecisionTreeClassifier(max_depth = 10)
t3
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t3.score(X_train,y_train)
# Out:
# 0.8849704142011834

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(t3,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3104
#            1       1.00      0.99      1.00      1121
#
#     accuracy                           1.00      4225
#    macro avg       1.00      1.00      1.00      4225
# weighted avg       1.00      1.00      1.00      4225

# %% [markdown]
# # max depth 6

# %%
t4 = DecisionTreeClassifier(max_depth = 10)
t4
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t4.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t4.score(X_train,y_train)
# Out:
# 0.8844970414201183

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(t4,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3104
#            1       1.00      0.99      1.00      1121
#
#     accuracy                           1.00      4225
#    macro avg       1.00      1.00      1.00      4225
# weighted avg       1.00      1.00      1.00      4225

# %% [markdown]
# # max depth 12

# %%
t5 = DecisionTreeClassifier(max_depth = 10)
t5
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t5.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
t5.score(X_train,y_train)
# Out:
# 0.8847337278106508

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(t5,
         feature_names = X_train.columns,
         filled=True)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3104
#            1       1.00      0.99      1.00      1121
#
#     accuracy                           1.00      4225
#    macro avg       1.00      1.00      1.00      4225
# weighted avg       1.00      1.00      1.00      4225

# %% [markdown]
# What model works best on the train dataset?
# model 1

# %%
t1.score(X_train, y_train)
# Out:
# 0.9981065088757396

# %%
t2.score(X_train, y_train)
# Out:
# 0.8847337278106508

# %%
t3.score(X_train, y_train)
# Out:
# 0.8849704142011834

# %%
t4.score(X_train, y_train)
# Out:
# 0.8844970414201183

# %%
t5.score(X_train, y_train)
# Out:
# 0.8847337278106508

# %% [markdown]
# What model works best on the validate dataset?
# t3 is the best model, however feature selection should be looked at next to optimize model

# %%
t1.score(X_validate, y_validate)
# Out:
# 0.7239176721078779

# %%
t2.score(X_validate, y_validate)
# Out:
# 0.7544357700496807

# %%
t3.score(X_validate, y_validate)
# Out:
# 0.7544357700496807

# %%
t4.score(X_validate, y_validate)
# Out:
# 0.7558552164655784

# %%
t5.score(X_validate, y_validate)
# Out:
# 0.7537260468417317

# %% [markdown]
# # with changing features

# %%
train.T
# Out:
#                                           5911     2479   5889     6087  \
# churn_encoded                             0.00     0.00   1.00     0.00
# tenure                                   26.00    47.00   1.00    69.00
# monthly_charges                          39.95    26.90  50.45    60.05
# total_charges                          1023.75  1250.85  50.45  4176.70
# gender_encoded                            1.00     0.00   0.00     1.00
# senior_citizen_encoded                    0.00     0.00   0.00     0.00
# partner_encoded                           0.00     1.00   0.00     0.00
# dependents_encoded                        1.00     0.00   0.00     0.00
# phone_service_encoded                     0.00     1.00   1.00     0.00
# paperless_billing_encoded                 1.00     0.00   1.00     1.00
# contract_type_One year                    1.00     1.00   0.00     0.00
# contract_type_Two year                    0.00     0.00   0.00     1.00
# ...

# %%
features = ['tenure','tech_support_Yes','internet_service_type_Fiber optic', 'multiple_lines_Yes','total_charges']
features
# Out:
# ['tenure',
#  'tech_support_Yes',
#  'internet_service_type_Fiber optic',
#  'multiple_lines_Yes',
#  'total_charges']

# %%
X_train[features].head()
# Out:
#       tenure  tech_support_Yes  internet_service_type_Fiber optic  \
# 5911      26                 0                                  0
# 2479      47                 0                                  0
# 5889       1                 0                                  0
# 6087      69                 1                                  0
# 785       51                 0                                  1
#
#       multiple_lines_Yes  total_charges
# 5911                   0        1023.75
# 2479                   1        1250.85
# 5889                   0          50.45
# 6087                   0        4176.70
# 785                    0        4475.90

# %%
#create
t7 = DecisionTreeClassifier(max_depth=9)

#fit 
#with features
t7.fit(X_train[features], y_train)

#transform 
#with features
t7.score(X_train[features], y_train)
# Out:
# 0.8331360946745562

# %%
t7.score(X_validate[features], y_validate)
# Out:
# 0.7757274662881476

# %%
print(classification_report(y_train, y_pred))
plt.figure(figsize = (12,6))
plot_tree(t7,
         feature_names = X_train.columns,
         filled=True)
plt.show()
